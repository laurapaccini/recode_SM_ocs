# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import xarray as xr
from matplotlib import cm
import mycolormaps as mycmap
import tools_plotting as to_plot

# %%
import tools_for_evolution as tools
from open_2d_2r_fields_notoprivr import *
from open_files_evolution_notoprivr import df_2r_c_i,df_2r_f_i

# %%
## WEST propagating systems - topography condition topo_median<100 UNROTATED  "t_i"
##Control experiment
direction = 'W'; dataf = df_2r_c_i.reset_index(drop=True).copy(); tl=500; lt1=-7; lt2=3; ln1=-73; ln2=-58; 
sm_ti_wc_WEST, df_2r_wc_WEST_ti = tools.select_SM_topo_region(dataf,sm_ti_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2); 
deaccu_ti_wc_WEST, _ = tools.select_SM_topo_region(dataf,deaccu_ti_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2); 
sfc_ti_wc_WEST, _    = tools.select_SM_topo_region(dataf,sfc_ti_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

# %%
del(dataf); 
##FixedSM experiment
dataf = df_2r_f_i.reset_index(drop=True).copy();tl=500; lt1=-7; lt2=3; ln1=-73; ln2=-58; 
sm_ti_wf_WEST, df_2r_wf_WEST_ti = tools.select_SM_topo_region(dataf,sm_ti_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wf_WEST, _ = tools.select_SM_topo_region(dataf,deaccu_ti_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wf_WEST, _    = tools.select_SM_topo_region(dataf,sfc_ti_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

# %%
## 3 and 6 Hours before (control and fixedSM)
tl=500; lt1=-7; lt2=3; ln1=-73; ln2=-58; 
df_stage_c_3hb = df_2r_c_i[(df_2r_c_i.time!='2018-03-31 02:00:00')&(df_2r_c_i.time!='2018-03-31 03:00:00')&(
                df_2r_c_i.time!='2018-03-31 04:00:00')&(df_2r_c_i.time!='2017-03-31 03:00:00')&(df_2r_c_i.time!='2017-03-31 04:00:00')].copy().reset_index(drop=True)
df_stage_f_3hb = df_2r_f_i[(df_2r_f_i.time!='2018-03-31 02:00:00')&(df_2r_f_i.time!='2018-03-31 03:00:00')&(
                df_2r_f_i.time!='2018-03-31 04:00:00')&(df_2r_f_i.time!='2017-03-31 03:00:00')&(df_2r_f_i.time!='2017-03-31 04:00:00')].copy().reset_index(drop=True)

sm_ti_wc_3hb_WEST, df_2r_wc_3hb_WEST_ti = tools.select_SM_topo_region(df_stage_c_3hb,sm_ti_3hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sm_ti_wf_3hb_WEST, df_2r_wf_3hb_WEST_ti = tools.select_SM_topo_region(df_stage_f_3hb,sm_ti_3hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wc_3hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_3hb,deaccu_ti_3hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wf_3hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_3hb,deaccu_ti_3hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wc_3hb_WEST, _    = tools.select_SM_topo_region(df_stage_c_3hb,sfc_ti_3hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wf_3hb_WEST, _    = tools.select_SM_topo_region(df_stage_f_3hb,sfc_ti_3hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

df_stage_c_6hb = df_2r_c_i[(df_2r_c_i.time!='2018-03-31 02:00:00')&(df_2r_c_i.time!='2018-03-31 03:00:00')&(
                df_2r_c_i.time!='2018-03-31 04:00:00')&(df_2r_c_i.time!='2018-03-31 05:00:00')&(
    df_2r_c_i.time!='2018-03-31 06:00:00')&(df_2r_c_i.time!='2018-03-31 07:00:00')&(df_2r_c_i.time!='2017-03-31 03:00:00')&(
    df_2r_c_i.time!='2017-03-31 04:00:00')&(df_2r_c_i.time!='2017-03-31 05:00:00')&(df_2r_c_i.time!='2017-03-31 06:00:00')&(
    df_2r_c_i.time!='2017-03-31 07:00:00')&(df_2r_c_i.time!='2019-03-31 05:00:00')&(df_2r_c_i.time!='2019-03-31 06:00:00')].copy().reset_index(drop=True)
df_stage_f_6hb = df_2r_f_i[(df_2r_f_i.time!='2018-03-31 02:00:00')&(df_2r_f_i.time!='2018-03-31 03:00:00')&(
                 df_2r_f_i.time!='2018-03-31 04:00:00')&(df_2r_f_i.time!='2018-03-31 05:00:00')&(
    df_2r_f_i.time!='2018-03-31 06:00:00')&(df_2r_f_i.time!='2018-03-31 07:00:00')&(df_2r_f_i.time!='2017-03-31 03:00:00')&(
    df_2r_f_i.time!='2017-03-31 04:00:00')&(df_2r_f_i.time!='2017-03-31 05:00:00')&(df_2r_f_i.time!='2017-03-31 06:00:00')&(
    df_2r_f_i.time!='2017-03-31 07:00:00')&(df_2r_f_i.time!='2019-03-31 05:00:00')&(df_2r_f_i.time!='2019-03-31 06:00:00')&(
    df_2r_f_i.time!='2019-03-31 07:00:00')].copy().reset_index(drop=True)

sm_ti_wc_6hb_WEST, df_2r_wc_6hb_WEST_ti = tools.select_SM_topo_region(df_stage_c_6hb,sm_ti_6hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sm_ti_wf_6hb_WEST, df_2r_wf_6hb_WEST_ti = tools.select_SM_topo_region(df_stage_f_6hb,sm_ti_6hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wc_6hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_6hb,deaccu_ti_6hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wf_6hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_6hb,deaccu_ti_6hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wc_6hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_6hb,sfc_ti_6hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wf_6hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_6hb,sfc_ti_6hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

# %%
#12 Hours before (control and fixedSM)
tl=500; lt1=-7; lt2=3; ln1=-73; ln2=-58; 
df_stage_c_12hb = df_2r_c_i[(df_2r_c_i.time!='2017-03-31 03:00:00')&(df_2r_c_i.time!='2017-03-31 04:00:00')&(
    df_2r_c_i.time!='2017-03-31 05:00:00')&(df_2r_c_i.time!='2017-03-31 06:00:00')&(df_2r_c_i.time!='2017-03-31 07:00:00')&(
    df_2r_c_i.time!='2017-03-31 08:00:00')&(df_2r_c_i.time!='2017-03-31 09:00:00')&(df_2r_c_i.time!='2017-03-31 10:00:00')&(
    df_2r_c_i.time!='2017-03-31 11:00:00')&(df_2r_c_i.time!='2017-03-31 12:00:00')&(df_2r_c_i.time!='2017-03-31 13:00:00')&(
    df_2r_c_i.time!='2018-03-31 02:00:00')&(df_2r_c_i.time!='2018-03-31 03:00:00')&(df_2r_c_i.time!='2018-03-31 04:00:00')&(
    df_2r_c_i.time!='2018-03-31 05:00:00')&(df_2r_c_i.time!='2018-03-31 06:00:00')&(df_2r_c_i.time!='2018-03-31 07:00:00')&(
    df_2r_c_i.time!='2018-03-31 08:00:00')&(df_2r_c_i.time!='2018-03-31 09:00:00')&(df_2r_c_i.time!='2018-03-31 10:00:00')&(
    df_2r_c_i.time!='2018-03-31 11:00:00')&(df_2r_c_i.time!='2018-03-31 12:00:00')&(df_2r_c_i.time!='2018-03-31 13:00:00')&(
    df_2r_c_i.time!='2019-03-31 05:00:00')&(df_2r_c_i.time!='2019-03-31 06:00:00')&(df_2r_c_i.time!='2019-03-31 08:00:00')&(
    df_2r_c_i.time!='2019-03-31 09:00:00')&(df_2r_c_i.time!='2019-03-31 10:00:00')&(df_2r_c_i.time!='2019-03-31 12:00:00')&(
    df_2r_c_i.time!='2019-03-31 13:00:00')].copy().reset_index(drop=True)


df_stage_f_12hb = df_2r_f_i[(df_2r_f_i.time!='2017-03-31 03:00:00')&(df_2r_f_i.time!='2017-03-31 04:00:00')&(
    df_2r_f_i.time!='2017-03-31 05:00:00')&(df_2r_f_i.time!='2017-03-31 06:00:00')&(df_2r_f_i.time!='2017-03-31 07:00:00')&(
    df_2r_f_i.time!='2017-03-31 08:00:00')&(df_2r_f_i.time!='2017-03-31 09:00:00')&(df_2r_f_i.time!='2017-03-31 10:00:00')&(
    df_2r_f_i.time!='2017-03-31 12:00:00')&(df_2r_f_i.time!='2017-03-31 13:00:00')&(df_2r_f_i.time!='2018-03-31 02:00:00')&(
    df_2r_f_i.time!='2018-03-31 03:00:00')&(df_2r_f_i.time!='2018-03-31 04:00:00')&(df_2r_f_i.time!='2018-03-31 05:00:00')&(
    df_2r_f_i.time!='2018-03-31 06:00:00')&(df_2r_f_i.time!='2018-03-31 07:00:00')&(df_2r_f_i.time!='2018-03-31 08:00:00')&(
    df_2r_f_i.time!='2018-03-31 09:00:00')&(df_2r_f_i.time!='2018-03-31 10:00:00')&(df_2r_f_i.time!='2018-03-31 11:00:00')&(
    df_2r_f_i.time!='2018-03-31 12:00:00')&(df_2r_f_i.time!='2018-03-31 13:00:00')&(df_2r_f_i.time!='2019-03-31 05:00:00')&(
    df_2r_f_i.time!='2019-03-31 06:00:00')&(df_2r_f_i.time!='2019-03-31 07:00:00')&(df_2r_f_i.time!='2019-03-31 08:00:00')&(
    df_2r_f_i.time!='2019-03-31 09:00:00')&(df_2r_f_i.time!='2019-03-31 10:00:00')&(df_2r_f_i.time!='2019-03-31 11:00:00')&(
    df_2r_f_i.time!='2019-03-31 12:00:00')&(df_2r_f_i.time!='2019-03-31 13:00:00')].copy().reset_index(drop=True)

sm_ti_wc_12hb_WEST, df_2r_wc_12hb_WEST_ti = tools.select_SM_topo_region(df_stage_c_12hb,sm_ti_12hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sm_ti_wf_12hb_WEST, df_2r_wf_12hb_WEST_ti = tools.select_SM_topo_region(df_stage_f_12hb,sm_ti_12hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wc_12hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_12hb,deaccu_ti_12hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wf_12hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_12hb,deaccu_ti_12hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wc_12hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_12hb,sfc_ti_12hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wf_12hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_12hb,sfc_ti_12hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

# %%
#24 Hours before (control and fixedSM)
tl=500; lt1=-7; lt2=3; ln1=-73; ln2=-58; 

df_stage_c_24hb = df_2r_c_i[(df_2r_c_i.time!='2017-03-31 03:00:00')&(df_2r_c_i.time!='2017-03-31 04:00:00')&(
    df_2r_c_i.time!='2017-03-31 05:00:00')&(df_2r_c_i.time!='2017-03-31 06:00:00')&(df_2r_c_i.time!='2017-03-31 07:00:00')&(
    df_2r_c_i.time!='2017-03-31 08:00:00')&(df_2r_c_i.time!='2017-03-31 09:00:00')&(df_2r_c_i.time!='2017-03-31 10:00:00')&(
    df_2r_c_i.time!='2017-03-31 11:00:00')&(df_2r_c_i.time!='2017-03-31 12:00:00')&(df_2r_c_i.time!='2017-03-31 13:00:00')&(
    df_2r_c_i.time!='2017-03-31 14:00:00')&(df_2r_c_i.time!='2017-03-31 15:00:00')&(df_2r_c_i.time!='2017-03-31 16:00:00')&(
    df_2r_c_i.time!='2017-03-31 17:00:00')&(df_2r_c_i.time!='2017-03-31 18:00:00')&(df_2r_c_i.time!='2017-03-31 19:00:00')&(
    df_2r_c_i.time!='2017-03-31 20:00:00')&(df_2r_c_i.time!='2017-03-31 21:00:00')&(df_2r_c_i.time!='2017-03-31 22:00:00')&(
    df_2r_c_i.time!='2017-03-31 23:00:00')&(df_2r_c_i.time!='2017-04-01 00:00:00')&(df_2r_c_i.time!='2017-04-01 01:00:00')&(
    df_2r_c_i.time!='2018-03-31 02:00:00')&(df_2r_c_i.time!='2018-03-31 03:00:00')&(df_2r_c_i.time!='2018-03-31 04:00:00')&(
    df_2r_c_i.time!='2018-03-31 05:00:00')&(df_2r_c_i.time!='2018-03-31 06:00:00')&(df_2r_c_i.time!='2018-03-31 07:00:00')&(
    df_2r_c_i.time!='2018-03-31 08:00:00')&(df_2r_c_i.time!='2018-03-31 09:00:00')&(df_2r_c_i.time!='2018-03-31 10:00:00')&(
    df_2r_c_i.time!='2018-03-31 11:00:00')&(df_2r_c_i.time!='2018-03-31 12:00:00')&(df_2r_c_i.time!='2018-03-31 13:00:00')&(
    df_2r_c_i.time!='2018-03-31 14:00:00')&(df_2r_c_i.time!='2018-03-31 15:00:00')&(df_2r_c_i.time!='2018-03-31 16:00:00')&(
    df_2r_c_i.time!='2018-03-31 17:00:00')&(df_2r_c_i.time!='2018-03-31 18:00:00')&(df_2r_c_i.time!='2018-03-31 19:00:00')&(
    df_2r_c_i.time!='2018-03-31 20:00:00')&(df_2r_c_i.time!='2018-03-31 21:00:00')&(df_2r_c_i.time!='2018-03-31 22:00:00')&(
    df_2r_c_i.time!='2018-03-31 23:00:00')&(df_2r_c_i.time!='2018-04-01 00:00:00')&(df_2r_c_i.time!='2018-04-01 01:00:00')&(
    df_2r_c_i.time!='2018-04-01 02:00:00')&(df_2r_c_i.time!='2018-04-01 03:00:00')&(df_2r_c_i.time!='2018-04-01 04:00:00')&(
    df_2r_c_i.time!='2019-03-31 05:00:00')&(df_2r_c_i.time!='2019-03-31 06:00:00')&(df_2r_c_i.time!='2019-03-31 08:00:00')&(
    df_2r_c_i.time!='2019-03-31 09:00:00')&(df_2r_c_i.time!='2019-03-31 10:00:00')&(df_2r_c_i.time!='2019-03-31 12:00:00')&(
    df_2r_c_i.time!='2019-03-31 13:00:00')&(df_2r_c_i.time!='2019-03-31 16:00:00')&(df_2r_c_i.time!='2019-03-31 17:00:00')&(
    df_2r_c_i.time!='2019-03-31 18:00:00')&(df_2r_c_i.time!='2019-03-31 19:00:00')&(df_2r_c_i.time!='2019-04-01 01:00:00')]

df_stage_f_24hb = df_2r_f_i[(df_2r_f_i.time!='2017-03-31 03:00:00')&(df_2r_f_i.time!='2017-03-31 04:00:00')&(
    df_2r_f_i.time!='2017-03-31 05:00:00')&(df_2r_f_i.time!='2017-03-31 06:00:00')&(df_2r_f_i.time!='2017-03-31 07:00:00')&(
    df_2r_f_i.time!='2017-03-31 08:00:00')&(df_2r_f_i.time!='2017-03-31 09:00:00')&(df_2r_f_i.time!='2017-03-31 10:00:00')&(
    df_2r_f_i.time!='2017-03-31 12:00:00')&(df_2r_f_i.time!='2017-03-31 13:00:00')&(df_2r_f_i.time!='2017-03-31 14:00:00')&(
    df_2r_f_i.time!='2017-03-31 15:00:00')&(df_2r_f_i.time!='2017-03-31 16:00:00')&(df_2r_f_i.time!='2017-03-31 17:00:00')&(
    df_2r_f_i.time!='2017-03-31 18:00:00')&(df_2r_f_i.time!='2017-03-31 19:00:00')&(df_2r_f_i.time!='2017-03-31 20:00:00')&(
    df_2r_f_i.time!='2017-03-31 21:00:00')&(df_2r_f_i.time!='2017-03-31 22:00:00')&(df_2r_f_i.time!='2017-03-31 23:00:00')&(
    df_2r_f_i.time!='2017-04-01 01:00:00')&(df_2r_f_i.time!='2018-03-31 02:00:00')&(df_2r_f_i.time!='2018-03-31 03:00:00')&(
    df_2r_f_i.time!='2018-03-31 04:00:00')&(df_2r_f_i.time!='2018-03-31 05:00:00')&(df_2r_f_i.time!='2018-03-31 06:00:00')&(
    df_2r_f_i.time!='2018-03-31 07:00:00')&(df_2r_f_i.time!='2018-03-31 08:00:00')&(df_2r_f_i.time!='2018-03-31 09:00:00')&(
    df_2r_f_i.time!='2018-03-31 10:00:00')&(df_2r_f_i.time!='2018-03-31 11:00:00')&(df_2r_f_i.time!='2018-03-31 12:00:00')&(
    df_2r_f_i.time!='2018-03-31 13:00:00')&(df_2r_f_i.time!='2018-03-31 14:00:00')&(df_2r_f_i.time!='2018-03-31 15:00:00')&(
    df_2r_f_i.time!='2018-03-31 16:00:00')&(df_2r_f_i.time!='2018-03-31 17:00:00')&(df_2r_f_i.time!='2018-03-31 18:00:00')&(
    df_2r_f_i.time!='2018-03-31 19:00:00')&(df_2r_f_i.time!='2018-03-31 20:00:00')&(df_2r_f_i.time!='2018-03-31 22:00:00')&(
    df_2r_f_i.time!='2018-03-31 23:00:00')&(df_2r_f_i.time!='2018-04-01 00:00:00')&(df_2r_f_i.time!='2018-04-01 01:00:00')&(
    df_2r_f_i.time!='2019-03-31 05:00:00')&(df_2r_f_i.time!='2019-03-31 06:00:00')&(df_2r_f_i.time!='2019-03-31 07:00:00')&(
    df_2r_f_i.time!='2019-03-31 08:00:00')&(df_2r_f_i.time!='2019-03-31 09:00:00')&(df_2r_f_i.time!='2019-03-31 10:00:00')&(
    df_2r_f_i.time!='2019-03-31 11:00:00')&(df_2r_f_i.time!='2019-03-31 12:00:00')&(df_2r_f_i.time!='2019-03-31 13:00:00')&(
    df_2r_f_i.time!='2019-03-31 14:00:00')&(df_2r_f_i.time!='2019-03-31 15:00:00')&(df_2r_f_i.time!='2019-03-31 16:00:00')&(
    df_2r_f_i.time!='2019-03-31 17:00:00')&(df_2r_f_i.time!='2019-03-31 18:00:00')&(df_2r_f_i.time!='2019-03-31 19:00:00')&(
    df_2r_f_i.time!='2019-03-31 20:00:00')&(df_2r_f_i.time!='2019-03-31 21:00:00')&(df_2r_f_i.time!='2019-03-31 22:00:00')&(
    df_2r_f_i.time!='2019-03-31 23:00:00')]

sm_ti_wc_24hb_WEST, df_2r_wc_24hb_WEST_ti = tools.select_SM_topo_region(df_stage_c_24hb,sm_ti_24hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sm_ti_wf_24hb_WEST, df_2r_wf_24hb_WEST_ti = tools.select_SM_topo_region(df_stage_f_24hb,sm_ti_24hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wc_24hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_24hb,deaccu_ti_24hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
deaccu_ti_wf_24hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_24hb,deaccu_ti_24hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wc_24hb_WEST, _ = tools.select_SM_topo_region(df_stage_c_24hb,sfc_ti_24hb_c,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)
sfc_ti_wf_24hb_WEST, _ = tools.select_SM_topo_region(df_stage_f_24hb,sfc_ti_24hb_f,topo_lim=tl,cd=direction,lati=lt1,latf=lt2,loni=ln1,lonf=ln2)

# %%
def sel_sizes(ds,df,cond_var='area_ob',var='',cond_valu=10e3,cond_vall=7e3,lim1=-100,lim2=100):
    """
    sel_var = ds.sel(time=df[(df[cond_var]>cond_vall)&(df[cond_var]<cond_valu)]['index'].tolist())[var].sel(lon=slice(lim1,lim2),lat=slice(lim1,lim2));
    """
    
    sel_var = ds.sel(time=((df[cond_var]>cond_vall)&(df[cond_var]<cond_valu)).tolist())[var].sel(lon=slice(lim1,lim2),lat=slice(lim1,lim2));
    
    return(sel_var)

# %% [markdown]
# #### Merging all composites by lag-time

# %%
### Amazon Control
var ='topo_std'; th = 150 ;
nc24 = (df_2r_wc_24hb_WEST_ti[var]<th);
nc12 = (df_2r_wc_12hb_WEST_ti[var]<th);
nc1 = (df_2r_wc_6hb_WEST_ti[var]<th); 
nc2 = (df_2r_wc_3hb_WEST_ti[var]<th);
nc5 = (df_2r_wc_WEST_ti[var]<th);     

df_evol_WEST_c = list([df_2r_wc_24hb_WEST_ti[nc24],df_2r_wc_12hb_WEST_ti[nc12],
                       df_2r_wc_6hb_WEST_ti[nc1],df_2r_wc_3hb_WEST_ti[nc2],df_2r_wc_WEST_ti[nc5]]);

sm_evol_c = list([sm_ti_wc_24hb_WEST.sel(time=nc24.tolist()),sm_ti_wc_12hb_WEST.sel(time=nc12.tolist()),
                  sm_ti_wc_6hb_WEST.sel(time=nc1.tolist()),
                  sm_ti_wc_3hb_WEST.sel(time=nc2.tolist()),sm_ti_wc_WEST.sel(time=nc5.tolist())])

pp_evol_c = list([deaccu_ti_wc_24hb_WEST.sel(time=nc24.tolist())[['tot_prec']],deaccu_ti_wc_12hb_WEST.sel(time=nc12.tolist())[['tot_prec']],
                  deaccu_ti_wc_6hb_WEST.sel(time=nc1.tolist())[['tot_prec']],
                  deaccu_ti_wc_3hb_WEST.sel(time=nc2.tolist())[['tot_prec']],deaccu_ti_wc_WEST.sel(time=nc5.tolist())[['tot_prec']]])

tg_evol_c = list([sfc_ti_wc_24hb_WEST.sel(time=nc24.tolist())[['t_g']],sfc_ti_wc_12hb_WEST.sel(time=nc12.tolist())[['t_g']],
                  sfc_ti_wc_6hb_WEST.sel(time=nc1.tolist())[['t_g']],
                  sfc_ti_wc_3hb_WEST.sel(time=nc2.tolist())[['t_g']], sfc_ti_wc_WEST.sel(time=nc5.tolist())[['t_g']]])

qvs_evol_c = list([sfc_ti_wc_24hb_WEST.sel(time=nc24.tolist())[['qv_s']],sfc_ti_wc_12hb_WEST.sel(time=nc12.tolist())[['qv_s']],
                   #sfc_ti_wc_9hb_WEST.sel(time=nc9.tolist())[['qv_s']],
                   sfc_ti_wc_6hb_WEST.sel(time=nc1.tolist())[['qv_s']],
                   sfc_ti_wc_3hb_WEST.sel(time=nc2.tolist())[['qv_s']],  sfc_ti_wc_WEST.sel(time=nc5.tolist())[['qv_s']]])
   
uw_evol_c = list([sfc_ti_wc_24hb_WEST.sel(time=nc24.tolist())[['u_10m']],sfc_ti_wc_12hb_WEST.sel(time=nc12.tolist())[['u_10m']],
                  sfc_ti_wc_6hb_WEST.sel(time=nc1.tolist())[['u_10m']],sfc_ti_wc_3hb_WEST.sel(time=nc2.tolist())[['u_10m']],
                  sfc_ti_wc_WEST.sel(time=nc5.tolist())[['u_10m']]]) 

vw_evol_c = list([sfc_ti_wc_24hb_WEST.sel(time=nc24.tolist())[['v_10m']],sfc_ti_wc_12hb_WEST.sel(time=nc12.tolist())[['v_10m']],
                  sfc_ti_wc_6hb_WEST.sel(time=nc1.tolist())[['v_10m']],sfc_ti_wc_3hb_WEST.sel(time=nc2.tolist())[['v_10m']],
                  sfc_ti_wc_WEST.sel(time=nc5.tolist())[['v_10m']]])

# %%
del(nc1,nc2,nc5,nc12,nc24); 
# Amazon FixedSM
nc24 = (df_2r_wf_24hb_WEST_ti[var]<th);
nc12 = (df_2r_wf_12hb_WEST_ti[var]<th) ;
nc1 = (df_2r_wf_6hb_WEST_ti[var]<th); 
nc2 = (df_2r_wf_3hb_WEST_ti[var]<th);
nc5 = (df_2r_wf_WEST_ti[var]<th);

df_evol_WEST_f = list([df_2r_wf_24hb_WEST_ti[nc24],df_2r_wf_12hb_WEST_ti[nc12],#df_2r_wf_9hb_WEST_ti[nc9],
                       df_2r_wf_6hb_WEST_ti[nc1],df_2r_wf_3hb_WEST_ti[nc2],
                           df_2r_wf_WEST_ti[nc5]])

sm_evol_f = list([sm_ti_wf_24hb_WEST.sel(time=nc24.tolist()),sm_ti_wf_12hb_WEST.sel(time=nc12.tolist()),
                  sm_ti_wf_6hb_WEST.sel(time=nc1.tolist()),sm_ti_wf_3hb_WEST.sel(time=nc2.tolist()),
                 sm_ti_wf_WEST.sel(time=nc5.tolist())])

pp_evol_f = list([deaccu_ti_wf_24hb_WEST.sel(time=nc24.tolist())[['tot_prec']],deaccu_ti_wf_12hb_WEST.sel(time=nc12.tolist())[['tot_prec']],
                  deaccu_ti_wf_6hb_WEST.sel(time=nc1.tolist())[['tot_prec']],
                  deaccu_ti_wf_3hb_WEST.sel(time=nc2.tolist())[['tot_prec']], deaccu_ti_wf_WEST.sel(time=nc5.tolist())[['tot_prec']]])

tg_evol_f = list([sfc_ti_wf_24hb_WEST.sel(time=nc24.tolist())[['t_g']],sfc_ti_wf_12hb_WEST.sel(time=nc12.tolist())[['t_g']],
                  #sfc_ti_wf_9hb_WEST.sel(time=nc9.tolist())[['t_g']],
                  sfc_ti_wf_6hb_WEST.sel(time=nc1.tolist())[['t_g']],sfc_ti_wf_3hb_WEST.sel(time=nc2.tolist())[['t_g']],
                  sfc_ti_wf_WEST.sel(time=nc5.tolist())[['t_g']]])

qvs_evol_f = list([sfc_ti_wf_24hb_WEST.sel(time=nc24.tolist())[['qv_s']],sfc_ti_wf_12hb_WEST.sel(time=nc12.tolist())[['qv_s']],
                   #sfc_ti_wf_9hb_WEST.sel(time=nc9.tolist())[['qv_s']], 
                   sfc_ti_wf_6hb_WEST.sel(time=nc1.tolist())[['qv_s']],sfc_ti_wf_3hb_WEST.sel(time=nc2.tolist())[['qv_s']],
                  sfc_ti_wf_WEST.sel(time=nc5.tolist())[['qv_s']]])

uw_evol_f = list([sfc_ti_wf_24hb_WEST.sel(time=nc24.tolist())[['u_10m']],sfc_ti_wf_12hb_WEST.sel(time=nc12.tolist())[['u_10m']],
                  sfc_ti_wf_6hb_WEST.sel(time=nc1.tolist())[['u_10m']],sfc_ti_wf_3hb_WEST.sel(time=nc2.tolist())[['u_10m']],
                  sfc_ti_wf_WEST.sel(time=nc5.tolist())[['u_10m']]]) 

vw_evol_f = list([sfc_ti_wf_24hb_WEST.sel(time=nc24.tolist())[['v_10m']],sfc_ti_wf_12hb_WEST.sel(time=nc12.tolist())[['v_10m']],
                  sfc_ti_wf_6hb_WEST.sel(time=nc1.tolist())[['v_10m']],sfc_ti_wf_3hb_WEST.sel(time=nc2.tolist())[['v_10m']],
                  sfc_ti_wf_WEST.sel(time=nc5.tolist())[['v_10m']]])

# %%
area_c = df_2r_wc_WEST_ti[(df_2r_wc_WEST_ti[var]<th)].area_ob.quantile([.1,.5,.9]);

# %%
area_f = df_2r_wf_WEST_ti[(df_2r_wf_WEST_ti[var]<th)].area_ob.quantile([.1,.5,.9]);

# %%
area_c
# Out:
# 0.1     3351.090
# 0.5     6040.020
# 0.9    14741.066
# Name: area_ob, dtype: float64

# %%
area_f
# Out:
# 0.1     3406.272
# 0.5     5484.080
# 0.9    16269.374
# Name: area_ob, dtype: float64

# %%
outplot = '/scratch/wcq7pz/output_plots/'

# %% [markdown]
# #### Figures 6 and 7 (subplots)

# %%
f, ax = plt.subplots(5, 3, figsize=(4,6),sharey=True,sharex=True,layout='constrained'); 
levs_sm=np.arange(-15,18,3); cticks_sm =np.arange(-12,16,6); lim_c=[1,5]; cbar_label1='[kg m$^{-2}$]';  cmap=mycmap.brownTOwhiteTOgreen
levs_qs=np.arange(-.6,.7,.1); cticks_qs=np.arange(-1.5,2,.5);cbar_label2='[g kg$^{-1}$]';cbar_label3='[K]';
levs_tg=np.arange(-1.3,1.5,.2); ticks_tg=np.arange(-1,2,1); lim1 = -108; lim2 = 108; sc = .02 ; sk = 6;
hours=[-24,-12,-6,-3,0]; axs = np.arange(0,6);
# Loop through each hour_lag dimension
for i in np.arange(0,5):
    var1_c = sel_sizes(sm_evol_c[i],df_evol_WEST_c[i],var='w_so',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    var2_c = sel_sizes(pp_evol_c[i],df_evol_WEST_c[i],var='tot_prec',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2)
    
    var1_f = sel_sizes(qvs_evol_c[i]*1e3,df_evol_WEST_c[i],var='qv_s',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    var3_f = sel_sizes(tg_evol_c[i],df_evol_WEST_c[i],var='t_g',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    
    varu_f = sel_sizes(uw_evol_c[i],df_evol_WEST_c[i],var='u_10m',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    varv_f = sel_sizes(vw_evol_c[i],df_evol_WEST_c[i],var='v_10m',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);

    bbar1=(var1_c-var1_c.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],0],levels=levs_sm,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],0],levels=lim_c, rasterized=True); ax[axs[i],0].set_ylabel(''); ax[axs[i],0].set_xlabel('')
    bbar2=(var1_f-var1_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],1],levels=levs_qs,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],1],levels=lim_c, rasterized=True); ax[axs[i],1].set_ylabel(''); ax[axs[i],1].set_xlabel('')
    bbar3=(var3_f-var3_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],2],levels=levs_tg,extend='both',cmap=mycmap.blueTOwhiteTOred,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],2],levels=lim_c, rasterized=True); ax[axs[i],2].set_ylabel(''); ax[axs[i],2].set_xlabel('')
    q1=ax[axs[i],0].quiver(varu_f.lon[::sk], varu_f.lat[::sk],np.squeeze((varu_f-varu_f.mean(['lon','lat'])).mean('time'))[::sk,::sk],
         np.squeeze((varv_f-varv_f.mean(['lon','lat'])).mean('time'))[::sk,::sk], scale=sc,headwidth=5, units='xy' )
    
# Plot mean for SM
ax[0, 0].set_title('Soil Moisture',fontsize=8.5); #a    
# Plot mean for Sfc Humidity
ax[0, 1].set_title('Sfc. Humidity',fontsize=8.5); ax[i, 1].set_yticks([-50,0,50])
# Plot mean for Sfc Temperature
ax[0, 2].set_title('Sfc. Temperature',fontsize=8.5); ax[i, 1].set_xticks([-50,0,50])
# Adjust tick size and tick label size
for axs in ax.flat:
    axs.tick_params(axis='both', which='both', size=6, labelsize=8) 
plt.subplots_adjust(hspace=0.2,wspace=0.15)
cax = plt.axes([0.135, 0.032, 0.22, 0.015])
cbar = plt.colorbar(bbar1, orientation='horizontal', cax=cax, cmap = cmap, label = cbar_label1, ticks=cticks_sm)
cax2 = plt.axes([0.28+0.135, 0.032, 0.22, 0.015])
cbar2 = plt.colorbar(bbar2, orientation='horizontal', cax=cax2, cmap = cmap, label = cbar_label2, ticks=cticks_qs)
cax3 = plt.axes([.55+0.135, 0.032, 0.22, 0.015])
cbar3 = plt.colorbar(bbar3, orientation='horizontal', cax=cax3, cmap = cmap, label = cbar_label3, ticks=ticks_tg)
cbar.ax.tick_params(direction='in',labelsize=8); cbar2.ax.tick_params(direction='in',labelsize=8)
cbar3.ax.tick_params(direction='in',labelsize=8)

plt.savefig(outplot+"fig6_big_systems.pdf", format="pdf",dpi=300,  bbox_inches="tight", transparent=True)

# %%
f, ax = plt.subplots(5, 3, figsize=(4,6),sharey=True,sharex=True,layout='constrained'); 
axs = np.arange(0,6);
# Loop through each hour_lag dimension
for i in np.arange(0,5):
    var1_c = sel_sizes(sm_evol_c[i],df_evol_WEST_c[i],var='w_so',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    var2_c = sel_sizes(pp_evol_c[i],df_evol_WEST_c[i],var='tot_prec',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2)
    
    var1_f = sel_sizes(qvs_evol_c[i]*1e3,df_evol_WEST_c[i],var='qv_s',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    var3_f = sel_sizes(tg_evol_c[i],df_evol_WEST_c[i],var='t_g',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    
    varu_f = sel_sizes(uw_evol_c[i],df_evol_WEST_c[i],var='u_10m',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    varv_f = sel_sizes(vw_evol_c[i],df_evol_WEST_c[i],var='v_10m',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);

    bbar1=(var1_c-var1_c.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],0],levels=levs_sm,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],0],levels=lim_c, rasterized=True); 
    ax[axs[i],0].set_ylabel(''); ax[axs[i],0].set_xlabel(''); ax[axs[i],0].set_ylim(-108,108); ax[axs[i],0].set_xlim(-108,108)
    bbar2=(var1_f-var1_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],1],levels=levs_qs,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],1],levels=lim_c, rasterized=True);
    ax[axs[i],1].set_ylabel(''); ax[axs[i],1].set_xlabel(''); ax[axs[i],1].set_ylim(-108,108); ax[axs[i],1].set_xlim(-108,108)
    bbar3=(var3_f-var3_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],2],levels=levs_tg,extend='both',cmap=mycmap.blueTOwhiteTOred,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],2],levels=lim_c, rasterized=True); 
    ax[axs[i],2].set_ylabel(''); ax[axs[i],2].set_xlabel(''); ax[axs[i],2].set_ylim(-108,108); ax[axs[i],2].set_xlim(-108,108)
    q1=ax[axs[i],0].quiver(varu_f.lon[::sk], varu_f.lat[::sk],np.squeeze((varu_f-varu_f.mean(['lon','lat'])).mean('time'))[::sk,::sk],
         np.squeeze((varv_f-varv_f.mean(['lon','lat'])).mean('time'))[::sk,::sk], scale=sc,headwidth=5, units='xy' )

# Plot mean for SM
ax[0, 0].set_title('Soil Moisture',fontsize=8.5); #a    
# Plot mean for Sfc. Humidity
ax[0, 1].set_title('Sfc. Humidity',fontsize=8.5); ax[i, 1].set_yticks([-50,0,50])
# Plot mean for sfc. Temperature
ax[0, 2].set_title('Sfc. Temperature',fontsize=8.5); ax[i, 1].set_xticks([-50,0,50])
# Adjust tick size and tick label size
for axs in ax.flat:
    axs.tick_params(axis='both', which='both', size=6, labelsize=8) 
plt.subplots_adjust(hspace=0.2,wspace=0.15)

cax = plt.axes([0.135, 0.032, 0.22, 0.015])
cbar = plt.colorbar(bbar1, orientation='horizontal', cax=cax, cmap = cmap, label = cbar_label1, ticks=cticks_sm)
cax2 = plt.axes([0.28+0.135, 0.032, 0.22, 0.015])
cbar2 = plt.colorbar(bbar2, orientation='horizontal', cax=cax2, cmap = cmap, label = cbar_label2, ticks=cticks_qs)
cax3 = plt.axes([.55+0.135, 0.032, 0.22, 0.015])
cbar3 = plt.colorbar(bbar3, orientation='horizontal', cax=cax3, cmap = cmap, label = cbar_label3, ticks=ticks_tg)
cbar.ax.tick_params(direction='in',labelsize=8); cbar2.ax.tick_params(direction='in',labelsize=8)
cbar3.ax.tick_params(direction='in',labelsize=8)

plt.savefig(outplot+"fig6_small_systems.pdf", format="pdf",dpi=300,  bbox_inches="tight", transparent=True)

# %%
f, ax = plt.subplots(5, 3, figsize=(4,6),sharey=True,sharex=True,layout='constrained'); 
axs = np.arange(0,5); 
# Loop through each hour_lag dimension
for i in np.arange(0,5):
    var1_c = sel_sizes(sm_evol_f[i],df_evol_WEST_f[i],var='w_so',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    var2_c = sel_sizes(pp_evol_f[i],df_evol_WEST_f[i],var='tot_prec',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2)
    
    var1_f = sel_sizes(qvs_evol_f[i]*1e3,df_evol_WEST_f[i],var='qv_s',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);
    var3_f = sel_sizes(tg_evol_f[i],df_evol_WEST_f[i],var='t_g',cond_vall=area_c[0.5],cond_valu=area_c[0.9],lim1=lim1,lim2=lim2);

    varu_f = sel_sizes(uw_evol_f[i],df_evol_WEST_f[i],var='u_10m',cond_vall=area_f[0.5],cond_valu=area_f[0.9],lim1=lim1,lim2=lim2);
    varv_f = sel_sizes(vw_evol_f[i],df_evol_WEST_f[i],var='v_10m',cond_vall=area_f[0.5],cond_valu=area_f[0.9],lim1=lim1,lim2=lim2);

    bbar1=(var1_c-var1_c.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],0],levels=levs_sm,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],0],levels=lim_c, rasterized=True); ax[axs[i],0].set_ylabel(''); ax[axs[i],0].set_xlabel('')
    bbar2=(var1_f-var1_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],1],levels=levs_qs,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],1],levels=lim_c, rasterized=True); ax[axs[i],1].set_ylabel(''); ax[axs[i],1].set_xlabel('')
    bbar3=(var3_f-var3_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],2],levels=levs_tg,extend='both',cmap=mycmap.blueTOwhiteTOred,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],2],levels=lim_c, rasterized=True); ax[axs[i],2].set_ylabel(''); ax[axs[i],2].set_xlabel('')
    q1=ax[axs[i],0].quiver(varu_f.lon[::sk], varu_f.lat[::sk],np.squeeze((varu_f-varu_f.mean(['lon','lat'])).mean('time'))[::sk,::sk],
         np.squeeze((varv_f-varv_f.mean(['lon','lat'])).mean('time'))[::sk,::sk], scale=sc,headwidth=5, units='xy' )

# Plot mean for SM
ax[0, 0].set_title('Soil Moisture',fontsize=8.5);ax[i, 1].set_yticks([-50,0,50])  
# Plot mean for sfc. Humidity
ax[0, 1].set_title('Sfc. Humidity',fontsize=8.5); ax[i, 1].set_xticks([-50,0,50])
# Plot mean for sfc. Temperature
ax[0, 2].set_title('Sfc. Temperature',fontsize=8.5); 
# Adjust tick size and tick label size
for axs in ax.flat:
    axs.tick_params(axis='both', which='both', size=6, labelsize=8) 
plt.subplots_adjust(hspace=0.2,wspace=0.15)
cax = plt.axes([0.135, 0.032, 0.22, 0.015])
cbar = plt.colorbar(bbar1, orientation='horizontal', cax=cax, cmap = cmap, label = cbar_label1, ticks=cticks_sm)
cax2 = plt.axes([0.28+0.135, 0.032, 0.22, 0.015])
cbar2 = plt.colorbar(bbar2, orientation='horizontal', cax=cax2, cmap = cmap, label = cbar_label2, ticks=cticks_qs)
cax3 = plt.axes([.55+0.135, 0.032, 0.22, 0.015])
cbar3 = plt.colorbar(bbar3, orientation='horizontal', cax=cax3, cmap = cmap, label = cbar_label3, ticks=ticks_tg)
cbar.ax.tick_params(direction='in',labelsize=8); cbar2.ax.tick_params(direction='in',labelsize=8)
cbar3.ax.tick_params(direction='in',labelsize=8)

plt.savefig(outplot+"fig7_big_systems.pdf", format="pdf",dpi=300,  bbox_inches="tight", transparent=True)

# %%
f, ax = plt.subplots(5, 3, figsize=(4,6),sharey=True,sharex=True,layout='constrained'); 
axs = np.arange(0,5); 
# Loop through each hour_lag dimension
for i in np.arange(0,5):
    var1_c = sel_sizes(sm_evol_f[i],df_evol_WEST_f[i],var='w_so',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    var2_c = sel_sizes(pp_evol_f[i],df_evol_WEST_f[i],var='tot_prec',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2)
    
    var1_f = sel_sizes(qvs_evol_f[i]*1e3,df_evol_WEST_f[i],var='qv_s',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);
    var3_f = sel_sizes(tg_evol_f[i],df_evol_WEST_f[i],var='t_g',cond_vall=area_c[0.1],cond_valu=area_c[0.5],lim1=lim1,lim2=lim2);

    varu_f = sel_sizes(uw_evol_f[i],df_evol_WEST_f[i],var='u_10m',cond_vall=area_f[0.1],cond_valu=area_f[0.5],lim1=lim1,lim2=lim2);
    varv_f = sel_sizes(vw_evol_f[i],df_evol_WEST_f[i],var='v_10m',cond_vall=area_f[0.1],cond_valu=area_f[0.5],lim1=lim1,lim2=lim2);

    bbar1=(var1_c-var1_c.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],0],levels=levs_sm,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],0],levels=lim_c, rasterized=True); 
    ax[axs[i],0].set_ylabel(''); ax[axs[i],0].set_xlabel(''); ax[axs[i],0].set_ylim(-108,108); ax[axs[i],0].set_xlim(-108,108)
    bbar2=(var1_f-var1_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],1],levels=levs_qs,extend='both',cmap=cmap,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],1],levels=lim_c, rasterized=True);
    ax[axs[i],1].set_ylabel(''); ax[axs[i],1].set_xlabel(''); ax[axs[i],1].set_ylim(-108,108); ax[axs[i],1].set_xlim(-108,108)
    bbar3=(var3_f-var3_f.mean(['lon','lat'])).mean('time').plot(ax=ax[axs[i],2],levels=levs_tg,extend='both',cmap=mycmap.blueTOwhiteTOred,  add_colorbar = False, rasterized=True); 
    (var2_c-var2_c.mean(['lon','lat'])).mean('time').plot.contour(ax=ax[axs[i],2],levels=lim_c, rasterized=True); 
    ax[axs[i],2].set_ylabel(''); ax[axs[i],2].set_xlabel(''); ax[axs[i],2].set_ylim(-108,108); ax[axs[i],2].set_xlim(-108,108)
    q1=ax[axs[i],0].quiver(varu_f.lon[::sk], varu_f.lat[::sk],np.squeeze((varu_f-varu_f.mean(['lon','lat'])).mean('time'))[::sk,::sk],
         np.squeeze((varv_f-varv_f.mean(['lon','lat'])).mean('time'))[::sk,::sk], scale=sc,headwidth=5, units='xy' )

# Plot mean for SM
ax[0, 0].set_title('Soil Moisture',fontsize=8.5);    
# Plot mean for sfc. Humidity
ax[0, 1].set_title('Sfc. Humidity',fontsize=8.5); ax[i, 1].set_yticks([-50,0,50])  
# Plot mean for sfc. Temperature
ax[0, 2].set_title('Sfc. Temperature',fontsize=8.5); ax[i, 1].set_xticks([-50,0,50])  
# Adjust tick size and tick label size
for axs in ax.flat:
    axs.tick_params(axis='both', which='both', size=6, labelsize=8) 
plt.subplots_adjust(hspace=0.2,wspace=0.15)
cax = plt.axes([0.135, 0.032, 0.22, 0.015])
cbar = plt.colorbar(bbar1, orientation='horizontal', cax=cax, cmap = cmap, label = cbar_label1, ticks=cticks_sm)
cax2 = plt.axes([0.28+0.135, 0.032, 0.22, 0.015])
cbar2 = plt.colorbar(bbar2, orientation='horizontal', cax=cax2, cmap = cmap, label = cbar_label2, ticks=cticks_qs)
cax3 = plt.axes([.55+0.135, 0.032, 0.22, 0.015])
cbar3 = plt.colorbar(bbar3, orientation='horizontal', cax=cax3, cmap = cmap, label = cbar_label3, ticks=ticks_tg)
cbar.ax.tick_params(direction='in',labelsize=8); cbar2.ax.tick_params(direction='in',labelsize=8)
cbar3.ax.tick_params(direction='in',labelsize=8)

plt.savefig(outplot+"fig7_small_systems.pdf", format="pdf",dpi=300,  bbox_inches="tight", transparent=True)
